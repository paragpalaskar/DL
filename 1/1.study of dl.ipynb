# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
 x = np.arange(-5,5,0.25)

# %%
x;

# %%
y = x*4.57+21.25

# %%
y;

# %%
plt.plot(x,y)

# %%
def sigmoid(z):
  val = 1/1+np.exp(-z)
  return val

# %%
y = sigmoid(x)

# %%
y
# Out:
# array([149.4131591 , 116.58428453,  91.0171313 ,  71.10541235,
#         55.59815003,  43.521082  ,  34.11545196,  26.79033992,
#         21.08553692,  16.64263188,  13.18249396,  10.48773584,
#          8.3890561 ,   6.75460268,   5.48168907,   4.49034296,
#          3.71828183,   3.11700002,   2.64872127,   2.28402542,
#          2.        ,   1.77880078,   1.60653066,   1.47236655,
#          1.36787944,   1.2865048 ,   1.22313016,   1.17377394,
#          1.13533528,   1.10539922,   1.082085  ,   1.06392786,
#          1.04978707,   1.03877421,   1.03019738,   1.02351775,
#          1.01831564,   1.01426423,   1.011109  ,   1.0086517 ])

# %%
plt.plot(x,y)

# %%
sigmoid(-2.6)
sigmoid(1.55)
sigmoid(0.355)
sigmoid(-.366)
# Out:
# 2.441955242654516

# %%
def relu(z):
  if z < 0:
    return 0
    eles
    return z

# %%
relx = [relu(a) for a in x]

# %%
plt.plot(x, relx)

# %%
def softmax(z):
  val = np.exp(z) / np.sum(np. exp(z))
  return val;

# %%
p = [1.45,2.67,0.48,0.91]
softmax(p)
# Out:
# array([0.18695017, 0.63323531, 0.07086964, 0.10894488])

# %%
plt.plot(x, np.tanh(x))
